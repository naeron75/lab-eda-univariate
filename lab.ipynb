# %%
import pandas as pd

# %%
df = pd.read_csv('./amz_uk_price_prediction_dataset.csv')

# %%
df.head()
# Out:
#    uid        asin                                              title  stars  \
# 0    1  B09B96TG33  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 1    2  B01HTH3C8S  Anker Soundcore mini, Super-Portable Bluetooth...    4.7
# 2    3  B09B8YWXDF  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 3    4  B09B8T5VGV  Echo Dot with clock (5th generation, 2022 rele...    4.7
# 4    5  B09WX6QD65  Introducing Echo Pop | Full sound compact Wi-F...    4.6
#
#    reviews  price  isBestSeller  boughtInLastMonth        category
# 0    15308  21.99         False                  0  Hi-Fi Speakers
# 1    98099  23.99          True                  0  Hi-Fi Speakers
# 2    15308  21.99         False                  0  Hi-Fi Speakers
# 3     7205  31.99         False                  0  Hi-Fi Speakers
# 4     1881  17.99         False                  0  Hi-Fi Speakers

# %%
categories_count = df['category'].value_counts()
categories_count
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
#                                            ...
# Alexa Built-In Devices                       107
# Motorbike Chassis                            107
# Plugs                                        107
# Smart Home Security & Lighting               104
# Smart Speakers                                54
# Name: count, Length: 296, dtype: int64

# %%
top_categories = df['category'].value_counts().head()
top_categories
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
categories_count.head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='category'>

# %%
top_categories.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['price'].mean()
# Out:
# 89.24380943923663

# %%
df['price'].mode()
# Out:
# 0    9.99
# Name: price, dtype: float64

# %%
df['price'].median()
# Out:
# 19.09

# %%
df['price'].describe()
# Out:
# count    2.443651e+06
# mean     8.924381e+01
# std      3.456089e+02
# min      0.000000e+00
# 25%      9.990000e+00
# 50%      1.909000e+01
# 75%      4.599000e+01
# max      1.000000e+05
# Name: price, dtype: float64

# %%
range = df['price'].max() - df['price'].min()
range
# Out:
# 100000.0

# %%
df['price'].var()
#There is a significant spread in prices. Variance is high
# Out:
# 119445.48532256528

# %%
df[df['price'] < 46]['price'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['price'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['stars'].mean()
# Out:
# 2.152836472966065

# %%
df['stars'].mode()
# Out:
# 0    0.0
# Name: stars, dtype: float64

# %%
df['stars'].median()
#Lots of 0 stars, probably simply people who didn't leave a review
# Out:
# 0.0

# %%
df['stars'].describe()
# Out:
# count    2.443651e+06
# mean     2.152836e+00
# std      2.194865e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      4.400000e+00
# max      5.000000e+00
# Name: stars, dtype: float64

# %%
df['stars'].var()
# Out:
# 4.81743402976196

# %%
range = df['stars'].max() - df['stars'].min()
range
# Out:
# 5.0

# %%
df['stars'].kurtosis()
# Out:
# -1.9260061280432985

# %%
df['stars'].skew()
# Out:
# 0.08120735761080985

# %%
#ratings leaning towards lower values and very much stacked on the lower side

# %%
df['stars'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
